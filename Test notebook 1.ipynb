# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Diem Chau**
#
#  Junior Data Scientist

# %% [markdown]
# *I am interested in Data science because I love solving real problems using mathematics and I want to know empirical ways to answer arbitrary, hard problems.*

# %% [markdown]
# ### The Following Code will generate a random integer between 10 and 50

# %%
import random

Random_int = random.randint(10,50)

print(Random_int)
# Out:
# 28

# %% [markdown]
# #### My interested technologies are:

# %% [markdown]
# ******
# ______
#
# 1. AI/ML/~~DL~~
# 2. Data Analytics
# 3. Cloud
# 4. AIoT
#
# ______
# ******
